# %%
# %load_ext autoreload
# %autoreload 2

from morphing_birds import Hawk3D, interactive_plot

# %%
hawk3d = Hawk3D("../data/mean_hawk_shape.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/002_Projects/Hawkflight/morphing_birds/src/morphing_birds/Hawk3D.py:46, in Hawk3D.load_csv(self, csv_path)
#      45 # Load and validate keypoints
# ---> 46 keypoints = self.load_csv_data(data)
#      47 self.validate_keypoints(keypoints)
#
# File ~/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/002_Projects/Hawkflight/morphing_birds/src/morphing_birds/Hawk3D.py:66, in Hawk3D.load_csv_data(self, csv_path)
#      57 """
#      58 Loads data from the CSV file.
#      59
#    (...)
#      64 - numpy.ndarray: Loaded data as a NumPy array.
#      65 """
# ---> 66 with open(csv_path, 'r') as file:
#      67     return np.loadtxt(file, delimiter=',', skiprows=0, dtype='str')
#
# TypeError: expected str, bytes or os.PathLike object, not ndarray
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 hawk3d = Hawk3D("../data/mean_hawk_shape.csv")
#
# File ~/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/002_Projects/Hawkflight/morphing_birds/src/morphing_birds/Hawk3D.py:21, in Hawk3D.__init__(self, csv_path)
#      19 skeleton_definition = HawkSkeletonDefinition()
#      20 super().__init__(skeleton_definition)
# ---> 21 self.load_csv(csv_path)
#      22 self.init_polygons(self.skeleton_definition.body_sections, self.csv_marker_names)
#
# File ~/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/002_Projects/Hawkflight/morphing_birds/src/morphing_birds/Hawk3D.py:54, in Hawk3D.load_csv(self, csv_path)
#      51     self.untransformed_shape = self.default_shape.copy()
#      53 except Exception as e:
# ---> 54     raise IOError(f"Error loading CSV file: {e}")
#
# OSError: Error loading CSV file: expected str, bytes or os.PathLike object, not ndarray

# %%
hawk3d.validate_polygon_shape()
# Out:
# Polygon shape is valid

# %%
hawk3d.marker_names
# Out:
# ['left_wingtip',
#  'right_wingtip',
#  'left_primary',
#  'right_primary',
#  'left_secondary',
#  'right_secondary',
#  'left_tailtip',
#  'right_tailtip']

# %%
hawk3d.skeleton_definition.get_marker_indices()
interactive_plot(hawk3d)
# Out:
# ['left_wingtip', 'right_wingtip', 'left_primary', 'right_primary', 'left_secondary', 'right_secondary', 'left_tailtip', 'right_tailtip', 'left_shoulder', 'left_tailbase', 'right_tailbase', 'right_shoulder', 'hood', 'tailpack']
# IntSlider(value=60, description='azimuth', max=90, min=-90, step=5)
# IntSlider(value=20, description='elevation', max=90, min=-15, step=5)
# Output()

# %%
interactive_plot(hawk3d)
# Out:
# IntSlider(value=60, description='azimuth', max=90, min=-90, step=5)
# IntSlider(value=20, description='elevation', max=90, min=-15, step=5)
# Output()
